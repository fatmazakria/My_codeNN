# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
num_puntos=100
con_puntos=[]
for  i in range(num_puntos):
    x1=np.random.normal(0.0,0.55)
    y1=x1*0.1+0.3+np.random.normal(0.0,0.03)
    con_puntos.append([x1,y1])

# %%
x_data =[v[0] for v in con_puntos]
y_data=[v[1] for v in con_puntos]
plt.plot(x_data,y_data,'r+' ,label='original data')
plt.legend()
plt. show()

# %%
w=tf.Variable(tf.random_uniform([1],-1.0,1.0))
b=tf.Variable(tf.zeros([1]))
y=w*x_data+b
loss=tf.reduce_mean(tf.square(y-y_data))
optimizer=tf.train.GradientDescentOptimizer(0.5)
train=optimizer.minimize(loss)
init=tf.global_variables_initializer()
sess=tf.Session()
sess.run(init)
for step in range (20):
    print(step,sess.run(w),sess.run(b))
    sess.run(train)
# Out:
# 0 [0.27258754] [0.]
# 1 [0.25431156] [0.2814713]
# 2 [0.21468058] [0.2831575]
# 3 [0.18490045] [0.286814]
# 4 [0.16230214] [0.28956163]
# 5 [0.14515616] [0.29164663]
# 6 [0.132147] [0.29322857]
# 7 [0.12227657] [0.29442886]
# 8 [0.11478758] [0.29533952]
# 9 [0.10910546] [0.2960305]
# 10 [0.10479427] [0.29655474]
# 11 [0.10152324] [0.2969525]
# 12 [0.09904142] [0.2972543]
# 13 [0.09715838] [0.29748327]
# 14 [0.09572966] [0.297657]
# 15 [0.09464566] [0.29778883]
# 16 [0.09382319] [0.29788885]
# 17 [0.09319916] [0.29796472]
# 18 [0.09272569] [0.2980223]
# 19 [0.09236645] [0.298066]

# %%
sess.run(init)
for step in range(50):
    sess.run(train)
    print(step, sess.run(w), sess.run(b))
    y_pred_value=sess.run(y)
    plt.plot(x_data,y_data,'go',x_data,y_pred_value,'r*')
    w_value=sess.run(w)
    b_value=sess.run(b)
    text="$ {} x + {}$".format(w_value,b.value)
    plt.text(-1,.4,text)
    plt.show()
# Out:
# 0 [0.01109695] [0.3103365]
# 1 [0.0373816] [0.3091234]
# 2 [0.05595766] [0.30846322]
# 3 [0.0690809] [0.30799666]
# 4 [0.07835194] [0.30766705]
# 5 [0.08490157] [0.3074342]
# 6 [0.08952862] [0.3072697]
# 7 [0.09279744] [0.3071535]
# 8 [0.09510674] [0.3070714]
# 9 [0.09673816] [0.3070134]
# 10 [0.0978907] [0.3069724]
# 11 [0.09870492] [0.30694348]
# 12 [0.09928013] [0.30692303]
# 13 [0.0996865] [0.30690858]
# 14 [0.09997358] [0.30689836]
# 15 [0.10017639] [0.30689114]
# 16 [0.10031968] [0.30688608]
# 17 [0.1004209] [0.30688247]
# 18 [0.1004924] [0.3068799]
# 19 [0.10054292] [0.30687812]
# 20 [0.10057861] [0.30687687]
# 21 [0.10060382] [0.30687597]
# 22 [0.10062163] [0.30687532]
# 23 [0.10063422] [0.30687487]
# 24 [0.10064311] [0.30687457]
# 25 [0.10064939] [0.30687433]
# 26 [0.10065383] [0.3068742]
# 27 [0.10065696] [0.30687407]
# 28 [0.10065918] [0.306874]
# 29 [0.10066074] [0.30687395]
# 30 [0.10066184] [0.3068739]
# 31 [0.10066263] [0.30687386]
# 32 [0.10066318] [0.30687386]
# 33 [0.10066357] [0.30687383]
# 34 [0.10066384] [0.30687383]
# 35 [0.10066403] [0.30687383]
# 36 [0.10066417] [0.30687383]
# 37 [0.10066427] [0.3068738]
# 38 [0.10066433] [0.3068738]
# 39 [0.10066438] [0.3068738]
# 40 [0.10066442] [0.3068738]
# 41 [0.10066444] [0.3068738]
# 42 [0.10066446] [0.3068738]
# 43 [0.10066447] [0.3068738]
# 44 [0.10066448] [0.3068738]
# 45 [0.10066449] [0.3068738]
# 46 [0.1006645] [0.3068738]
# 47 [0.1006645] [0.3068738]
# 48 [0.1006645] [0.3068738]
# 49 [0.1006645] [0.3068738]
